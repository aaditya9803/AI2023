# %% [markdown]
# # Notebook Imports and Packages

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# # Cost Function
# ## $ f(x) = x^2 + x + 1 $
# ## $$ f(x) = x^2 + x 1 $$

# %%
def f(x):
    return x**2 + x + 1

# %%
# make data with numpy
x_1 = np.linspace (start=-3, stop=3, num=100)

# %% [markdown]
# ## Slope and derivatives

# %%
#python function for the derivatives of f(x) which is called df(x)
def df(x):
    return 2*x + 1

# %% [markdown]
# ## Plot function and derivative side by side

# %%
# Gradient Descent
new_x = 3
previous_x = 0
step_multiplier = 0.1
for n in range(30):
    previous_x = new_x
    gradient = df(previous_x)
    new_x = previous_x - step_multiplier * gradient
print ('local minimum occurs at:', new_x)
print ('sloper or df(x) value at this point is', df(new_x))
# Out:
# local minimum occurs at: -0.4956672098625011
# sloper or df(x) value at this point is 0.008665580274997753

# %%
#plot function and derivative side by side
plt.figure(figsize=(10,5))
#1 Chart: Cost function
plt.subplot(1,2,1)
plt.xlim(-3,3)
plt.ylim(0,8)
plt.title('cost function', fontsize=17)
plt.ylabel('f(x): Co', fontsize =16)
plt.plot(x_1 , f(x_1), color='blue', linewidth = 3)
#2 Chart: Derivatives
plt.subplot(1,2,2)
plt.xlim(-2,3)
plt.ylim(-3,6)
plt.title('slope of the cost function', fontsize=17)
plt.ylabel('df(x)', fontsize =16)
plt.xlabel('x', fontsize =16)
plt.plot(x_1, df(x_1), color='skyblue', linewidth = 5)

# %%
# Gradient Descent
new_x = 3
previous_x = 0
step_multiplier = 0.1
for n in range(30):
    previous_x = new_x
    gradient = df(previous_x)
    new_x = previous_x - step_multiplier * gradient
print ('local minimum occurs at:', new_x)
print ('sloper or df(x) value at this point is', df(new_x))
# Out:
# local minimum occurs at: -0.4956672098625011
# sloper or df(x) value at this point is 0.008665580274997753

# %%
# Gradient Descent
new_x = 3
previous_x = 0
step_multiplier = 0.1
precision = 0.00001
x_list = [new_x]
slope_list = [df(new_x)]
for n in range(30):
    previous_x = new_x
    gradient = df(previous_x)
    new_x = previous_x - step_multiplier * gradient
    step_size = abs(new_x-previous_x)
    x_list. append(new_x)
    slope_list.append(df(new_x))
    if step_size < precision:
        print('loop ran this many times:', n)
        break
print ('local minimum occurs at:', new_x)
print ('sloper or df(x) value at this point is', df(new_x))
print ('f(x) value or cost at this point is :', f(new_x))
# Out:
# local minimum occurs at: -0.4956672098625011
# sloper or df(x) value at this point is 0.008665580274997753
# f(x) value or cost at this point is : 0.7500187730703756

# %%
#plot function and derivative side by side
plt.figure(figsize=(10,5))
#1 Chart: Cost function
plt.subplot(1,2,1)
plt.xlim(-3,3)
plt.ylim(0,8)
plt.title('cost function', fontsize=17)
plt.ylabel('f(x): Co', fontsize =16)
plt.plot(x_1 , f(x_1), color='blue', linewidth = 3)
values = np.array(x_list)
plt.scatter(x_list, f(values), color='red', s=100, alpha=0.6)
#2 Chart: Derivatives
plt.subplot(1,2,2)
plt.xlim(-2,3)
plt.ylim(-3,6)
plt.title('slope of the cost function', fontsize=17)
plt.ylabel('df(x)', fontsize =16)
plt.xlabel('x', fontsize =16)
plt.plot(x_1, df(x_1), color='skyblue', linewidth = 5)
plt.scatter(x_list, slope_list, color='red', s=100, alpha=0.5)
plt.show()

# %% [markdown]
# # Example 2 - Multiple Minima vs Initial Guess and Advanced Function

# %% [markdown]
# ## $$g(x)=x^4-4x^2+5$$

# %%
#making the data
x_2 = np.linspace(-2,2,1000)
# Writing the g(x) function and the dg(x) function in python
def g(x):
    return x**4-4*x**2+5
def dg(x):
    return 4*x**3-8*x

# %%
#will use the python function to make it easier
def gradient_descent(derivative_func,initial_guess,multiplier=0.02,precision0=0.001,max_iter=300):
    new_x = initial_guess
    x_list=[new_x]
    slope_list=[derivative_func(new_x)]
    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x=previous_x-multiplier*gradient
        step_size=abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))
        if step_size < precision:
            break
    return new_x, x_list, slope_list

# %%
local_min,list_x,deriv_list = gradient_descent(dg,0.5,0.2,0.001)
print('local min occurs at:',local_min)
print('Number of steps:',len(list_x))
# Out:
# local min occurs at: -0.0009281348367865815
# Number of steps: 225

# %%
#plot function and derivative side by side
plt.figure(figsize=(10,5))
#1 Chart: Cost function
plt.subplot(1,2,1)
plt.xlim(-3,3)
plt.ylim(0,8)
plt.title('cost function', fontsize=17)
plt.ylabel('g(x): Co', fontsize =16)
plt.plot(x_2 , g(x_2), color='blue', linewidth = 3)
values = np.array(list_x)
plt.scatter(list_x, g(values), color='red', s=100, alpha=0.6)
plt.show()

# %% [markdown]
# # Example 3 - Divergence, Overflow and Python Tuples
# ## $$h(x)=x^5-2x^4+2$$

# %%
#making data
x_3 = np.linspace(start=-2.5,stop=2.5,num=1000)
def h(x):
    return x**5-2*x**4+2
def dh(x):
    return 5*x**4 - 8*x**3

# %%
#We change some parameters and argument values for plotting h(x).
# LETS GO >>>>>> LETS GOOOOOOOOOOOOOOOOO >>> STUDY HARDDD
#plot function and derivative side by side
local_min,list_x,deriv_list = gradient_descent(derivative_func=dh,initial_guess=-0.2,max_iter=70)
plt.figure(figsize=(15,5))
#1 Chart: Cost function
plt.subplot(1,2,1)
plt.xlim(-1.2,2.5)
plt.ylim(-1,4)
plt.title('cost function', fontsize=17)
plt.ylabel('h(x): Co', fontsize =16)
plt.plot(x_3 , h(x_3), color='blue', linewidth = 3)
values = np.array(list_x)
plt.scatter(list_x, h(values), color='red', s=100, alpha=0.6)
#2 Chart: Derivatives
plt.subplot(1,2,2)
plt.xlim(-1,2)
plt.ylim(-4,5)
plt.title('slope of the cost function', fontsize=17)
plt.ylabel('dh(x)', fontsize =16)
plt.xlabel('x', fontsize =16)
plt.plot(x_3, dh(x_3), color='skyblue', linewidth = 5)
print('local min occurs at:',local_min)
print('cost at this min is',h(local_min))
print('Number of steps:',len(list_x))
print('deriv - list ', deriv_list)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)
plt.show()
# Out:
# local min occurs at: -2071072.4470816324
# cost at this min is -3.810455326061589e+31
# Number of steps: 71
# ...

# %%
import sys

# %%
sys.version
# Out:
# '3.10.7 (tags/v3.10.7:6cc6b13, Sep  5 2022, 14:08:36) [MSC v.1933 64 bit (AMD64)]'

# %%
sys.float_info.max
# Out:
# 1.7976931348623157e+308
